# %% [markdown]
# # Final Evaluation - Part 1

# %% [markdown]
# First, create a dataset of more than 500 cases using any of the APIs listed [here](https://github.com/public-apis/public-apis) or [here](https://github.com/realpython/list-of-python-api-wrappers) or by scraping the website of your choice. You will submit your notebook and the csv data file.

# %% [markdown]
# We used the public API of the "Penguin Publishing" (http://www.penguinrandomhouse.biz/webservices/rest/) to create a dataset of 501 books which included the word "shakespeare" in their title. More specifically, we created a function which, after specifying the search word and the number of books required, could extract the specified number of books with that search word in their title.

# %%
import requests
import pandas as pd

def get_books(search_term, count):
    
    df = []
    
    # The API only allows to get 100 books at a time, so we have to loop over the given books count, 100 books at a time
    for i in range(0, count, 100):
        
        # Specify at which book index to start
        start_index = i 
        
        # Specify how many books to get this time - either 100 if we will have another loop over the count 
        # or the remaining book count if we finish looping with this loop
        if count - 100 - i < 0:
            max_count = count - i
        else:
            max_count = 100
        
        # Make call to the API and get the information in JSON format
        base_url   = 'https://reststop.randomhouse.com/resources/titles/'
        parameters = {'start': start_index,
                      'max':max_count,
                      'expandLevel': 1, # Get all possible information
                      'search': search_term}
        headers = {'Accept': 'application/json',
                   'Content-Type': 'application/json'}
        r = requests.get(base_url, parameters, headers = headers).json()
        
        # If the API call output is not empty (this could happen if the specified parameter 'count' is larger 
        # than the number of available books with this search term), append the output to the output dataframe.
        # Also, specify two cases of how to append the output to the output dataframe - one case when the number 
        # of books in the API output is 1 and another case when the number of books in the API output is larger than 1.
        if 'title' in r:
            if max_count == 1:
                df.append(pd.DataFrame([r['title']]))
            else:
                df.append(pd.DataFrame(r['title']))
    
    return df

# %%
# Extract 501 books with the word 'shakespeare' in their title. Note that the output will contain either 
# the specified number of books or the maximum number of books available with the search term in their title.

books = get_books('shakespeare', 501)
df = pd.concat(books, ignore_index = True)

# %%
# Length of the output dataframe
len(df)
# Out:
# 501

# %%
df
# Out:
#                                                   @uri            author  \
# 0    https://reststop.randomhouse.com/resources/tit...  RUDNICKI, STEFAN
# 1    https://reststop.randomhouse.com/resources/tit...   EPSTEIN, NORRIE
# 2    https://reststop.randomhouse.com/resources/tit...    CRYSTAL, DAVID
# 3    https://reststop.randomhouse.com/resources/tit...     CLARK, SANDRA
# 4    https://reststop.randomhouse.com/resources/tit...    BRADLEY, A. C.
# ..                                                 ...               ...
# 496  https://reststop.randomhouse.com/resources/tit...     DOESCHER, IAN
# 497  https://reststop.randomhouse.com/resources/tit...     DOESCHER, IAN
# 498  https://reststop.randomhouse.com/resources/tit...     DOESCHER, IAN
# 499  https://reststop.randomhouse.com/resources/tit...     DOESCHER, IAN
# 500  https://reststop.randomhouse.com/resources/tit...     DOESCHER, IAN
#
#                                                authors  \
# 0    {'authorId': {'@contributortype': 'E V', '$': ...
# 1    {'authorId': {'@contributortype': 'A', '$': '8...
# 2    {'authorId': [{'@contributortype': '1', '$': '...
# 3    {'authorId': {'@contributortype': 'E', '$': '2...
# 4    {'authorId': [{'@contributortype': 'U', '$': '...
# ..                                                 ...
# 496  {'authorId': [{'@contributortype': 'A', '$': '...
# 497  {'authorId': [{'@contributortype': 'A', '$': '...
# 498  {'authorId': {'@contributortype': 'A', '$': '1...
# 499  {'authorId': {'@contributortype': 'A', '$': '1...
# 500  {'authorId': {'@contributortype': 'A', '$': '1...
#
#                                              authorbio  \
# 0    <b>Stefan Rudnicki</b>&#160;is an avid audiobo...
# 1    <b>Norrie Epstein</b> has lectured extensively...
# 2    David Crystal is one of the most authoritative...
# 3    The author of many books on Shakespeare and En...
# 4    <b>A. C. Bradley</b> was born in Cheltenham in...
# ..                                                 ...
# 496  <b>Ian Doescher&#160;</b>is the <i>New York Ti...
# 497  <b>Ian Doescher&#160;</b>is the <i>New York Ti...
# 498  <b>Ian Doescher</b> is the <i>New York Times</...
# 499  <b>Ian Doescher</b> is the <i>New York Times</...
# 500  <b>Ian Doescher</b>&#160;is the&#160;<i>New Yo...
#
#                                        authorweb awards characters  \
# 0    Collected and Introduced by Stefan Rudnicki   None       None
# 1                                 Norrie Epstein   None       None
# 2                                  David Crystal   None       None
# 3                                   Sandra Clark   None       None
# 4                                  A. C. Bradley   None       None
# ..                                           ...    ...        ...
# 496                                 Ian Doescher   None       None
# 497                                 Ian Doescher   None       None
# 498                                 Ian Doescher   None       None
# 499                                 Ian Doescher   None       None
# 500                                 Ian Doescher   None       None
#
#     contributorfirst1 contributorfirst2 contributorlast1  ... rgabout  \
# 0              Stefan            Stefan         Rudnicki  ...     NaN
# 1              Norrie               NaN          Epstein  ...     NaN
# 2               David               Ben          Crystal  ...     NaN
# 3              Sandra               NaN            Clark  ...     NaN
# 4               A. C.              John          Bradley  ...     NaN
# ..                ...               ...              ...  ...     ...
# 496               Ian              Kent         Doescher  ...     NaN
# 497               Ian              Kent         Doescher  ...     NaN
# 498               Ian               NaN         Doescher  ...     NaN
# 499               Ian               NaN         Doescher  ...     NaN
# 500               Ian               NaN         Doescher  ...     NaN
#
#     rgauthbio rgcopy rgdiscussion bonusfeature authqanda authordesktop  \
# 0         NaN    NaN          NaN          NaN       NaN           NaN
# 1         NaN    NaN          NaN          NaN       NaN           NaN
# 2         NaN    NaN          NaN          NaN       NaN           NaN
# 3         NaN    NaN          NaN          NaN       NaN           NaN
# 4         NaN    NaN          NaN          NaN       NaN           NaN
# ..        ...    ...          ...          ...       ...           ...
# 496       NaN    NaN          NaN          NaN       NaN           NaN
# 497       NaN    NaN          NaN          NaN       NaN           NaN
# 498       NaN    NaN          NaN          NaN       NaN           NaN
# 499       NaN    NaN          NaN          NaN       NaN           NaN
# 500       NaN    NaN          NaN          NaN       NaN           NaN
#
#     authordesktoplinktext authordesktoplinkurl sgmtDesc
# 0                     NaN                  NaN      NaN
# 1                     NaN                  NaN      NaN
# 2                     NaN                  NaN      NaN
# 3                     NaN                  NaN      NaN
# 4                     NaN                  NaN      NaN
# ..                    ...                  ...      ...
# 496                   NaN                  NaN      NaN
# 497                   NaN                  NaN      NaN
# 498                   NaN                  NaN      NaN
# 499                   NaN                  NaN      NaN
# 500                   NaN                  NaN      NaN
#
# [501 rows x 63 columns]

# %%
# Dataframe's column names
df.columns
# Out:
# Index(['@uri', 'author', 'authors', 'authorbio', 'authorweb', 'awards',
#        'characters', 'contributorfirst1', 'contributorfirst2',
#        'contributorlast1', 'contributorlast2', 'division', 'flapcopy',
#        'formatcode', 'formatname', 'imprint', 'isbn', 'isbn10',
#        'isbn10hyphenated', 'isbn13hyphenated', 'keyword', 'onsaledate',
#        'pages', 'pricecanada', 'priceusa', 'relatedisbns', 'salestatus',
#        'subjectcategory1', 'subjectcategory2', 'subjectcategory3',
#        'subjectcategorydescription1', 'subjectcategorydescription2',
#        'subjectcategorydescription3', 'subtitle', 'tgpdf', 'themes',
#        'titleauthisbn', 'titleshort', 'titlesubtitleauthisbn', 'titleweb',
#        'updatedOn', 'webdomains', 'links', 'workid', 'contributorfirst3',
#        'contributorlast3', 'jacketquotes', 'excerpt', 'tableofcontents',
#        'agerange', 'agerangecode', 'acmartflap', 'subformat', 'rgabout',
#        'rgauthbio', 'rgcopy', 'rgdiscussion', 'bonusfeature', 'authqanda',
#        'authordesktop', 'authordesktoplinktext', 'authordesktoplinkurl',
#        'sgmtDesc'],
#       dtype='object')

# %% [markdown]
# We can see that the output dataframe is not very clean, for example, some columns contain dictionaries as their elements and some text is in HTML format, making it hard to read. Thus we will clean the dataset a little bit.

# %%
# Create a function which converts HTML text to normal readable text, and use it on non-readable columns

import html2text
import math
def convert_from_html_to_text(html_text):
    if html_text==html_text:
        html_text = html_text.replace("<b>", "")
        html_text = html_text.replace("</b>", "")
        html_text = html_text.replace("<i>", "'")  # <i> and </i> are used for text in Italics, and in this case identify 
        html_text = html_text.replace("</i>", "'") # book titles and such, thus we put those words in quotation marks instead
        html_text = html2text.html2text(html_text)
    return html_text

df['authorbio_text'] = df['authorbio'].apply(convert_from_html_to_text)
df['flapcopy_text'] = df['flapcopy'].apply(convert_from_html_to_text)
df['jacketquotes_text'] = df['jacketquotes'].apply(convert_from_html_to_text)
df['excerpt_text'] = df['excerpt'].apply(convert_from_html_to_text)
df['tableofcontents_text'] = df['tableofcontents'].apply(convert_from_html_to_text)
df['acmartflap_text'] = df['acmartflap'].apply(convert_from_html_to_text)

# %%
# Example of how HTML text looks like after being converted to normal text

print(df['authorbio'][0])
print('\n')
print(df['authorbio_text'][0])
# Out:
# <b>Stefan Rudnicki</b>&#160;is an avid audiobook narrator, receiving numerous Earphones Awards from&#160;<i>AudioFile</i>&#160;magazine. He is also a Grammy-winning audiobook producer.
#
#
# Stefan Rudnicki is an avid audiobook narrator, receiving numerous Earphones
# Awards from 'AudioFile' magazine. He is also a Grammy-winning audiobook
# producer.

# %%
# Extract link URLs and link descriptions from the 'links' column

def extract_linktext(links):
    if links is not None:
        linktext=[]
        if isinstance(links['link'], dict):
            linktext = links['link']['linktext']
        else:
            for i in range(len(links['link'])):
                linktext.append(links['link'][i]['linktext'])
        return linktext
    
def extract_linkurl(links):  
    if links is not None:
        url=[]
        if isinstance(links['link'], dict):
            url = links['link']['url']
        else:
            for i in range(len(links['link'])):
                url.append(links['link'][i]['url'])
        return url

df['links_url'] = df['links'].apply(extract_linkurl)
df['links_description'] = df['links'].apply(extract_linktext)

# %%
# Extract award name, year, ISBN and award level from the column 'awards'

def extract_award_name(awards):
    if awards is not None:
        award_name=[]
        if isinstance(awards['award'], dict):
            award_name = awards['award']['awarddesc']
        else:
            for i in range(len(awards['award'])):
                award_name.append(awards['award'][i]['awarddesc'])
        return award_name

def extract_award_year(awards):
    if awards is not None:
        award_year=[]
        if isinstance(awards['award'], dict):
            award_year = awards['award']['awardyear']
        else:
            for i in range(len(awards['award'])):
                award_year.append(awards['award'][i]['awardyear'])
        return award_year
    
def extract_award_isbn(awards):
    if awards is not None:
        award_isbn=[]
        if isinstance(awards['award'], dict):
            award_isbn = awards['award']['awardisbn']
        else:
            for i in range(len(awards['award'])):
                award_isbn.append(awards['award'][i]['awardisbn'])
        return award_isbn

def extract_award_level(awards):
    if awards is not None:
        award_level=[]
        if isinstance(awards['award'], dict):
            award_level = awards['award']['awardlevel']
        else:
            for i in range(len(awards['award'])):
                award_level.append(awards['award'][i]['awardlevel'])
        return award_level

    
df['award_name'] = df['awards'].apply(extract_award_name)
df['award_year'] = df['awards'].apply(extract_award_year)
df['award_isbn'] = df['awards'].apply(extract_award_isbn)
df['award_level'] = df['awards'].apply(extract_award_level)

# %%
# Put all relevant columns to a new dataframe 

df_clean = df[['workid', 'authorweb', 'titleweb', 'subtitle', 'pages', 'formatcode', 'formatname', 'division', 'imprint', 
    'salestatus', 'onsaledate', 'updatedOn', 'pricecanada', 'priceusa', 'isbn', 'isbn10', 'isbn10hyphenated', 
    'isbn13hyphenated', 'themes', 'agerange', 'subjectcategory1', 'subjectcategorydescription1', 
    'subjectcategory2', 'subjectcategorydescription2', 'subjectcategory3', 'subjectcategorydescription3',
    'authorbio_text', 'tableofcontents_text', 'excerpt_text', 'flapcopy_text', 'acmartflap_text', 'jacketquotes_text',
    'links_url', 'links_description', 'award_name', 'award_year', 'award_isbn', 'award_level'
    ]]

# %%
df_clean.sample(10)
# Out:
#      workid                            authorweb  \
# 429  204501                  William Shakespeare
# 361  324152                  William Shakespeare
# 174  299479                  William Shakespeare
# 319  213819                  William Shakespeare
# 69   317729                  E. Foley, B. Coates
# 393  555885                  William Shakespeare
# 413  205696                  William Shakespeare
# 180  303494                 Lilian Jackson Braun
# 104    9278  John Barton Foreword by Trevor Nunn
# 244  610951                           Emma Smith
#
#                                      titleweb  \
# 429                   The Taming of the Shrew
# 361                The Merry Wives of Windsor
# 174  Pericles/Cymbeline/The Two Noble Kinsmen
# 319                      The Comedy of Errors
# 69           Shakespeare Basics for Grown-Ups
# 393                      Antony and Cleopatra
# 413                               Richard III
# 180              The Cat Who Knew Shakespeare
# 104                       Playing Shakespeare
# 244                       This Is Shakespeare
#
#                                        subtitle pages formatcode  \
# 429                                         NaN   224         EL
# 361                                         NaN   160         EL
# 174                                         NaN   736         MM
# 319                                         NaN   176         TR
# 69   Everything You Need to Know About the Bard   336         TR
# 393                                         NaN   192         EL
# 413                                         NaN   272         EL
# 180                                         NaN   256         MM
# 104                            An Actor's Guide   288         EL
# 244                                         NaN     0         DN
#
#                         formatname             division             imprint  \
# 429                          eBook   Random House Group      Modern Library
# 361                          eBook  Penguin Adult HC/TR    Penguin Classics
# 174                      Paperback        Berkley / NAL              Signet
# 319                Trade Paperback   Random House Group      Modern Library
# 69                 Trade Paperback  Penguin Adult HC/TR               Plume
# 393                          eBook  Penguin Adult HC/TR    Penguin Classics
# 413                          eBook   Random House Group      Modern Library
# 180                      Paperback        Berkley / NAL             Berkley
# 104                          eBook                Knopf              Anchor
# 244  Unabridged Audiobook Download                Audio  Random House Audio
#
#     salestatus  ...                                       excerpt_text  \
# 429         EL  ...  Introduction  \n  \nTHE "TAMING" AND THE "SHRE...
# 361         EL  ...                                                NaN
# 174         IP  ...                                                NaN
# 319         IP  ...  Act 1 Scene 1 running scene 1  \n  \nEnter Duk...
# 69          IP  ...  INTRODUCTION\n\nWilliam Shakespeare is without...
# 393         EL  ...                                                NaN
# 413         EL  ...  Chapter 1  \n  \nlist of parts  \n  \nRICHARD,...
# 180         IP  ...                                                NaN
# 104         EL  ...  part one  \n  \nObjective Things  \n  \nchapte...
# 244         EL  ...  INTRODUCTION  \n  \nWhy should you read a book...
#
#                                          flapcopy_text acmartflap_text  \
# 429  A robust and bawdy battle of the sexes, this e...             NaN
# 361  The acclaimed Pelican Shakespeare series edite...             NaN
# 174  The plays collected here follow: the journeys ...             NaN
# 319  "I see two husbands, or mine eyes deceive me."...             NaN
# 69   An essential guide to Shakespeare, from the in...             NaN
# 393  The acclaimed Pelican Shakespeare series edite...             NaN
# 413  An exciting new edition of the complete works ...             NaN
# 180  In this mystery in the' 'bestselling Cat Who s...             NaN
# 104  Playing Shakespeare' 'is the premier guide to ...             NaN
# 244  An electrifying new study that investigates th...             NaN
#
#                                      jacketquotes_text  \
# 429                                                NaN
# 361                                                NaN
# 174                                                NaN
# 319  Praise for 'William Shakespeare: Complete Work...
# 69   "An obvious candidate to take to a desert isla...
# 393  "Gorgeous new Shakespeare paperbacks."  \n--Ma...
# 413                                                NaN
# 180  Praise for Lilian Jackson Braun and the Cat Wh...
# 104  "One of the sanest, wisest, and most practical...
# 244  'Advance Praise from the U.K.:'  \n  \n"I admi...
#
#                                              links_url   links_description  \
# 429                                               None                None
# 361                                               None                None
# 174                                               None                None
# 319                                               None                None
# 69                                                None                None
# 393                                               None                None
# 413                                               None                None
# 180                                               None                None
# 104                                               None                None
# 244  https://soundcloud.com/penguin-audio/this-is-s...  Link to Audio Clip
#
#     award_name award_year award_isbn award_level
# 429       None       None       None        None
# 361       None       None       None        None
# 174       None       None       None        None
# 319       None       None       None        None
# 69        None       None       None        None
# 393       None       None       None        None
# 413       None       None       None        None
# 180       None       None       None        None
# 104       None       None       None        None
# 244       None       None       None        None
#
# [10 rows x 38 columns]

# %%
# Save the dataframe to a CSV file

df_clean.to_csv('penguin_books_scraped.csv', encoding='utf8', index=False)

# %%
# Check if everything is fine

df_clean_read = pd.read_csv('penguin_books_scraped.csv', encoding='utf8')
df_clean_read.sample(10)
# Out:
#      workid                                          authorweb  \
# 394  555886                                William Shakespeare
# 491  597934                                       Ian Doescher
# 58   555886                                William Shakespeare
# 170  294240                                William Shakespeare
# 155  326574                                William Shakespeare
# 87   164696                                William Shakespeare
# 479  622223                                Elizabeth J. Duncan
# 209  164679  William Shakespeare   Edited by David Bevingto...
# 297  205693                                William Shakespeare
# 260  163697                                     Francine Segan
#
#                                               titleweb  \
# 394                                Measure for Measure
# 491  William Shakespeare's Get Thee Back to the Fut...
# 58                                 Measure for Measure
# 170               Titus Andronicus and Timon of Athens
# 155                                   Henry IV, Part I
# 87                            King John and Henry VIII
# 479                                  Ill Met By Murder
# 209                                             Hamlet
# 297                                          King Lear
# 260                              Shakespeare's Kitchen
#
#                                               subtitle  pages formatcode  \
# 394                                                NaN    160         EL
# 491                                                NaN    176         EL
# 58                                                 NaN    160         TR
# 170                                                NaN    464         MM
# 155                                                NaN    336         MM
# 87                                                 NaN    592         EL
# 479             A Shakespeare in the Catskills Mystery    288         EL
# 209                                                NaN    384         MM
# 297                                                NaN    272         TR
# 260  Renaissance Recipes for the Contemporary Cook:...    288         EL
#
#           formatname             division             imprint salestatus  ...  \
# 394            eBook  Penguin Adult HC/TR    Penguin Classics         EL  ...
# 491            eBook          Quirk Books         Quirk Books         EL  ...
# 58   Trade Paperback  Penguin Adult HC/TR    Penguin Classics         IP  ...
# 170        Paperback        Berkley / NAL              Signet         IP  ...
# 155        Paperback        Berkley / NAL              Signet         IP  ...
# 87             eBook          Bantam Dell     Bantam Classics         EL  ...
# 479            eBook   Crooked Lane Books  Crooked Lane Books         EL  ...
# 209        Paperback          Bantam Dell     Bantam Classics         IP  ...
# 297  Trade Paperback   Random House Group      Modern Library         IP  ...
# 260            eBook   Random House Group        Random House         EL  ...
#
#                                           excerpt_text  \
# 394                                                NaN
# 491                                                NaN
# 58                                                 NaN
# 170                                                NaN
# 155                                                NaN
# 87   'Introduction  \n'  \n  \nThe Life and Death o...
# 479                                                NaN
# 209  Dramatis Personae\n\n*\n\nghost of Hamlet, the...
# 297  'Chapter One  \n  \n  \nAct 1 Scene 1 running ...
# 260  Some pigeons, Davy, a couple of  \nshort-legge...
#
#                                          flapcopy_text  \
# 394  The acclaimed Pelican Shakespeare series edite...
# 491  Celebrate 'Back to the Future' with this illus...
# 58   The acclaimed Pelican Shakespeare series edite...
# 170  As part of the Signet Classics Shakespeare Ser...
# 155  This edition of Shakespeare's Henry IV, Part 1...
# 87   These two history plays--one written in the ea...
# 479  It's the most important night of the year for ...
# 209  One of the greatest plays of all time, the com...
# 297  King Lear is Shakespeare's bleakest and profou...
# 260  "Shakespeare's Kitchen not only reveals, somet...
#
#                                        acmartflap_text  \
# 394                                                NaN
# 491                                                NaN
# 58                                                 NaN
# 170                                                NaN
# 155                                                NaN
# 87                                                 NaN
# 479                                                NaN
# 209  One of the greatest plays of all time, the com...
# 297  King Lear is Shakespeare's bleakest and profou...
# 260                                                NaN
#
#                                      jacketquotes_text  \
# 394  "Gorgeous new Shakespeare paperbacks."  \n--Ma...
# 491  "A weird and wonderful Shakespearean play."--'...
# 58   "Gorgeous new Shakespeare paperbacks."  \n--Ma...
# 170                                                NaN
# 155                                                NaN
# 87                                                 NaN
# 479  Praise for 'Ill Met by Murder':  \n  \n"Duncan...
# 209  Praise for 'William Shakespeare: Complete Work...
# 297                                                NaN
# 260  '  \n'"Shakespeare's Kitchen treats four-hundr...
#
#                                              links_url  \
# 394                                                NaN
# 491                                                NaN
# 58                                                 NaN
# 170                                                NaN
# 155                                                NaN
# 87                                                 NaN
# 479                                                NaN
# 209  http://www.randomhouse.com/bantamdell/shakespe...
# 297                                                NaN
# 260                                                NaN
#
#                                      links_description award_name award_year  \
# 394                                                NaN        NaN        NaN
# 491                                                NaN        NaN        NaN
# 58                                                 NaN        NaN        NaN
# 170                                                NaN        NaN        NaN
# 155                                                NaN        NaN        NaN
# 87                                                 NaN        NaN        NaN
# 479                                                NaN        NaN        NaN
# 209  Click here for the official Bantam Dell Shakes...        NaN        NaN
# 297                                                NaN        NaN        NaN
# 260                                                NaN        NaN        NaN
#
#     award_isbn award_level
# 394        NaN         NaN
# 491        NaN         NaN
# 58         NaN         NaN
# 170        NaN         NaN
# 155        NaN         NaN
# 87         NaN         NaN
# 479        NaN         NaN
# 209        NaN         NaN
# 297        NaN         NaN
# 260        NaN         NaN
#
# [10 rows x 38 columns]
